# %%
import tensorflow as tf

class VegetableClassifier(tf.keras.Model):
    def __init__(self):
        super(VegetableClassifier, self).__init__()

        # Convolutional layers
        self.conv1 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu')
        self.maxpool1 = tf.keras.layers.MaxPooling2D((2, 2))
        self.conv2 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu')
        self.maxpool2 = tf.keras.layers.MaxPooling2D((2, 2))

        # Flatten layer
        self.flatten = tf.keras.layers.Flatten()

        # Fully connected layers
        self.fc1 = tf.keras.layers.Dense(128, activation='relu')
        self.dropout = tf.keras.layers.Dropout(0.25)
        self.fc2 = tf.keras.layers.Dense(num_classes, activation='softmax')

    def call(self, inputs):
        x = self.conv1(inputs)
        x = self.maxpool1(x)
        x = self.conv2(x)
        x = self.maxpool2(x)

        x = self.flatten(x)
        x = self.fc1(x)
        x = self.dropout(x)
        x = self.fc2(x)

        return x

# Load the vegetable classification dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.vegetable_classification.load_data()

# Preprocess the images
x_train = x_train / 255.0
x_test = x_test / 255.0

# Create the model
model = VegetableClassifier()

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [1], in <cell line: 35>()
#      32         return x
#      34 # Load the vegetable classification dataset
# ---> 35 (x_train, y_train), (x_test, y_test) = tf.keras.datasets.vegetable_classification.load_data()
#      37 # Preprocess the images
#      38 x_train = x_train / 255.0
#
# AttributeError: module 'keras.api._v2.keras.datasets' has no attribute 'vegetable_classification'

# %%
import tensorflow as tf

class VegetableClassifier(tf.keras.Model):
    def __init__(self):
        super(VegetableClassifier, self).__init__()

        # Convolutional layers
        self.conv1 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu')
        self.maxpool1 = tf.keras.layers.MaxPooling2D((2, 2))
        self.conv2 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu')
        self.maxpool2 = tf.keras.layers.MaxPooling2D((2, 2))

        # Flatten layer
        self.flatten = tf.keras.layers.Flatten()

        # Fully connected layers
        self.fc1 = tf.keras.layers.Dense(128, activation='relu')
        self.dropout = tf.keras.layers.Dropout(0.25)
        self.fc2 = tf.keras.layers.Dense(num_classes, activation='softmax')

    def call(self, inputs):
        x = self.conv1(inputs)
        x = self.maxpool1(x)
        x = self.conv2(x)
        x = self.maxpool2(x)

        x = self.flatten(x)
        x = self.fc1(x)
        x = self.dropout(x)
        x = self.fc2(x)

        return x

# Load the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Preprocess the images
x_train = x_train / 255.0
x_test = x_test / 255.0

# Create the model
model = VegetableClassifier()

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
# Out:
# ...
#  29720576/170498071 [====>.........................] - ETA: 3:39
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 35>()
#      32         return x
#      34 # Load the CIFAR-10 dataset
# ---> 35 (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
#      37 # Preprocess the images
#      38 x_train = x_train / 255.0
#
# File ~\anaconda3\lib\site-packages\keras\datasets\cifar10.py:81, in load_data()
#      79 dirname = "cifar-10-batches-py"
#      80 origin = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
# ---> 81 path = get_file(
#      82     dirname,
#      83     origin=origin,
#      84     untar=True,
#      85     file_hash=(  # noqa: E501
#      86         "6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce"
#      87     ),
#      88 )
#      90 num_train_samples = 50000
# ...
