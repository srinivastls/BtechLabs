# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# Define the Gaussian Naive Bayes Classifier
class GaussianNaiveBayes:
    def fit(self, X, y):
        self.classes = np.unique(y)
        self.mean = {}
        self.var = {}
        self.prior = {}

        for c in self.classes:
            X_c = X[y == c]
            self.mean[c] = np.mean(X_c, axis=0)
            self.var[c] = np.var(X_c, axis=0)
            self.prior[c] = len(X_c) / len(X)

    def predict(self, X):
        predictions = []

        for x in X:
            posteriors = []

            for c in self.classes:
                prior = np.log(self.prior[c])
                likelihood = np.sum(np.log(self.pdf(c, x)))
                posterior = prior + likelihood
                posteriors.append(posterior)

            predictions.append(self.classes[np.argmax(posteriors)])

        return np.array(predictions)

    def pdf(self, class_label, x):
        mean = self.mean[class_label]
        var = self.var[class_label]
        num = np.exp(-(x - mean) ** 2 / (2 * var))
        den = np.sqrt(2 * np.pi * var)
        return num / den

# Create and fit the Gaussian Naive Bayes classifier
gnb = GaussianNaiveBayes()
gnb.fit(X_train, y_train)

# Make predictions on the test set
y_pred = gnb.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

# %%
#!/usr/bin/env python
# coding: utf-8

# Importing Libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import sympy as sp
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# PCA Function
def pca(X, n_components=0.95):
    mean_vector = np.mean(X, axis=0)
    covariance_matrix = np.cov(X, rowvar=False)
    eigen_values, eigen_vectors = np.linalg.eig(covariance_matrix)
    ind = np.argsort(eigen_values)[::-1]
    sorted_eigen_values = eigen_values[ind]
    
    if n_components >= 1:
        d1 = int(n_components)
    else:
        total_variance = np.sum(sorted_eigen_values)
        selected_eigen_values = []
        cum_variance = 0
        i = 0
        while cum_variance < n_components * total_variance:
            cum_variance += sorted_eigen_values[i]
            selected_eigen_values.append(sorted_eigen_values[i])
            i += 1
        d1 = len(selected_eigen_values)
        
    sorted_eigen_vectors = eigen_vectors[ind]
    final_eigen_vectors = sorted_eigen_vectors[:, :d1]
    
    X1 = np.dot(X, final_eigen_vectors)
    return X1

# Bayes Classifier
def bayes_classifier(X_train, y_train, X_test):
    classes, class_counts = np.unique(y_train, return_counts=True)
    no_of_classes = len(classes)
    total_data_points = len(y_train)
    apriori_probabilities = class_counts / total_data_points
    class_split_training_data = {}
    
    for c in classes:
        class_split_training_data[c] = []
        for j in range(len(y_train)):
            if c == y_train[j]:
                class_split_training_data[c].append(X_train[j])
        class_split_training_data[c] = np.array(class_split_training_data[c])
    
    mean_vectors = [np.mean(class_split_training_data[c], axis=0) for c in classes]
    covariance_matrices = [np.cov(class_split_training_data[c], rowvar=False) for c in classes]
    inverse_covariance_matrices = [np.linalg.inv(covariance_matrices[c]) for c in range(len(classes))]
    dimensions = len(X_train[0])
    det_covariance_matrices = [sp.Matrix(covariance_matrices[c]).det() for c in range(len(classes))]

    y_pred = []
    
    for X in X_test:
        probability_values = {}
        class_count = 0
        for c in classes:
            
            p_xw = np.exp(-0.5 * np.dot(np.dot((X - mean_vectors[class_count]).T, inverse_covariance_matrices[class_count]), (X - mean_vectors[class_count]))) / (((2 * np.pi) ** (dimensions / 2)) * np.power(det_covariance_matrices[c], 0.5))
            p_wx = p_xw * apriori_probabilities[class_count]
            probability_values[c] = p_wx
            class_count += 1
        y_pred.append(max(probability_values, key=probability_values.get))
    
    return y_pred

# Importing Dataset
dataset = pd.read_csv('face.csv')
dataset = dataset.fillna(dataset.mean())
print(dataset)
# Test-Train Split
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# Principal Component Analysis
X_train_pca = pca(X_train, 0.95)
X_test_pca = pca(X_test, 0.95)

# Model Training & Evaluation
y_pred = bayes_classifier(X_train_pca, y_train, X_test_pca)
accuracy = accuracy_score(y_test, y_pred)
print(f"The Accuracy of this model is {accuracy*100}%")
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.309917  0.367769  0.417355  0.442149  0.528926  0.607438  0.657025
# 1    0.454545  0.471074  0.512397  0.557851  0.595041  0.640496  0.681818
# 2    0.318182  0.400826  0.491736  0.528926  0.586777  0.657025  0.681818
# 3    0.198347  0.194215  0.194215  0.194215  0.190083  0.190083  0.243802
# 4    0.500000  0.545455  0.582645  0.623967  0.648760  0.690083  0.694215
# ..        ...       ...       ...       ...       ...       ...       ...
# 395  0.400826  0.495868  0.570248  0.632231  0.648760  0.640496  0.661157
# 396  0.367769  0.367769  0.351240  0.301653  0.247934  0.247934  0.367769
# 397  0.500000  0.533058  0.607438  0.628099  0.657025  0.632231  0.657025
# 398  0.214876  0.219008  0.219008  0.223140  0.210744  0.202479  0.276859
# 399  0.516529  0.462810  0.280992  0.252066  0.247934  0.367769  0.574380
#
#             7         8         9  ...      4087      4088      4089  \
# 0    0.677686  0.690083  0.685950  ...  0.669422  0.652893  0.661157
# 1    0.702479  0.710744  0.702479  ...  0.157025  0.136364  0.148760
# 2    0.685950  0.702479  0.698347  ...  0.132231  0.181818  0.136364
# 3    0.404959  0.483471  0.516529  ...  0.636364  0.657025  0.685950
# 4    0.714876  0.723140  0.731405  ...  0.161157  0.177686  0.173554
# ..        ...       ...       ...  ...       ...       ...       ...
# 395  0.636364  0.665289  0.698347  ...  0.396694  0.264463  0.099174
# 396  0.512397  0.574380  0.628099  ...  0.334711  0.289256  0.285124
# 397  0.669422  0.673554  0.702479  ...  0.148760  0.152893  0.161157
# 398  0.400826  0.487603  0.549587  ...  0.392562  0.367769  0.409091
# 399  0.615702  0.661157  0.615702  ...  0.264463  0.293388  0.301653
#
#          4090      4091      4092      4093      4094      4095  target
# 0    0.475207  0.132231  0.148760  0.152893  0.161157  0.157025       0
# 1    0.152893  0.152893  0.152893  0.152893  0.152893  0.152893       0
# 2    0.128099  0.148760  0.144628  0.140496  0.148760  0.152893       0
# 3    0.727273  0.743802  0.764463  0.752066  0.752066  0.739669       0
# 4    0.177686  0.177686  0.177686  0.177686  0.173554  0.173554       0
# ..        ...       ...       ...       ...       ...       ...     ...
# 395  0.181818  0.243802  0.247934  0.161157  0.157025  0.136364      39
# 396  0.338843  0.404959  0.458678  0.487603  0.512397  0.549587      39
# 397  0.161157  0.173554  0.157025  0.177686  0.148760  0.190083      39
# 398  0.479339  0.524793  0.545455  0.574380  0.590909  0.603306      39
# 399  0.293388  0.322314  0.322314  0.359504  0.355372  0.384298      39
#
# [400 rows x 4097 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 91>()
#      88 X_test_pca = pca(X_test, 0.95)
#      90 # Model Training & Evaluation
# ---> 91 y_pred = bayes_classifier(X_train_pca, y_train, X_test_pca)
#      92 accuracy = accuracy_score(y_test, y_pred)
#      93 print(f"The Accuracy of this model is {accuracy*100}%")
#
# Input In [1], in bayes_classifier(X_train, y_train, X_test)
#      57 inverse_covariance_matrices = [np.linalg.inv(covariance_matrices[c]) for c in range(len(classes))]
#      58 dimensions = len(X_train[0])
# ---> 59 det_covariance_matrices = [sp.Matrix(covariance_matrices[c]).det() for c in range(len(classes))]
#      61 y_pred = []
#      63 for X in X_test:
#
# Input In [1], in <listcomp>(.0)
#      57 inverse_covariance_matrices = [np.linalg.inv(covariance_matrices[c]) for c in range(len(classes))]
#      58 dimensions = len(X_train[0])
# ---> 59 det_covariance_matrices = [sp.Matrix(covariance_matrices[c]).det() for c in range(len(classes))]
#      61 y_pred = []
#      63 for X in X_test:
#
# File ~\anaconda3\lib\site-packages\sympy\matrices\matrices.py:131, in MatrixDeterminant.det(self, method, iszerofunc)
#     130 def det(self, method="bareiss", iszerofunc=None):
# --> 131     return _det(self, method=method, iszerofunc=iszerofunc)
#
# File ~\anaconda3\lib\site-packages\sympy\matrices\determinant.py:670, in _det(M, method, iszerofunc)
#     668     det = _det_DOM(M[b, b])
#     669 elif method == "bareiss":
# --> 670     det = M[b, b]._eval_det_bareiss(iszerofunc=iszerofunc)
#     671 elif method == "berkowitz":
#     672     det = M[b, b]._eval_det_berkowitz()
#
# File ~\anaconda3\lib\site-packages\sympy\matrices\matrices.py:107, in MatrixDeterminant._eval_det_bareiss(self, iszerofunc)
#     106 def _eval_det_bareiss(self, iszerofunc=_is_zero_after_expand_mul):
# --> 107     return _det_bareiss(self, iszerofunc=iszerofunc)
#
# File ~\anaconda3\lib\site-packages\sympy\matrices\determinant.py:743, in _det_bareiss(M, iszerofunc)
#     738     return M.one
#     739     # sympy/matrices/tests/test_matrices.py contains a test that
#     740     # suggests that the determinant of a 0 x 0 matrix is one, by
#     741     # convention.
# --> 743 return bareiss(M)
#
# File ~\anaconda3\lib\site-packages\sympy\matrices\determinant.py:732, in _det_bareiss.<locals>.bareiss(mat, cumm)
#     729         return cancel(ret)
#     730     return ret
# --> 732 return sign*bareiss(M._new(mat.rows - 1, mat.cols - 1, entry), pivot_val)
#
# File ~\anaconda3\lib\site-packages\sympy\matrices\determinant.py:732, in _det_bareiss.<locals>.bareiss(mat, cumm)
#     729         return cancel(ret)
#     730     return ret
# --> 732 return sign*bareiss(M._new(mat.rows - 1, mat.cols - 1, entry), pivot_val)
#
#     [... skipping similar frames: _det_bareiss.<locals>.bareiss at line 732 (60 times)]
#
# File ~\anaconda3\lib\site-packages\sympy\matrices\determinant.py:732, in _det_bareiss.<locals>.bareiss(mat, cumm)
#     729         return cancel(ret)
#     730     return ret
# --> 732 return sign*bareiss(M._new(mat.rows - 1, mat.cols - 1, entry), pivot_val)
#
# File ~\anaconda3\lib\site-packages\sympy\matrices\repmatrix.py:340, in MutableRepMatrix._new(cls, copy, *args, **kwargs)
#     338     rows, cols, flat_list = args
#     339 else:
# --> 340     rows, cols, flat_list = cls._handle_creation_inputs(*args, **kwargs)
#     341     flat_list = list(flat_list) # create a shallow copy
#     343 rep = cls._flat_list_to_DomainMatrix(rows, cols, flat_list)
#
# File ~\anaconda3\lib\site-packages\sympy\matrices\matrices.py:1127, in MatrixBase._handle_creation_inputs(cls, *args, **kwargs)
#    1124     flat_list = []
#    1125     for i in range(rows):
#    1126         flat_list.extend(
# -> 1127             [cls._sympify(op(cls._sympify(i), cls._sympify(j)))
#    1128              for j in range(cols)])
#    1130 # Matrix(2, 2, [1, 2, 3, 4])
#    1131 elif len(args) == 3 and is_sequence(args[2]):
#
# File ~\anaconda3\lib\site-packages\sympy\matrices\matrices.py:1127, in <listcomp>(.0)
#    1124     flat_list = []
#    1125     for i in range(rows):
#    1126         flat_list.extend(
# -> 1127             [cls._sympify(op(cls._sympify(i), cls._sympify(j)))
#    1128              for j in range(cols)])
#    1130 # Matrix(2, 2, [1, 2, 3, 4])
#    1131 elif len(args) == 3 and is_sequence(args[2]):
#
# File ~\anaconda3\lib\site-packages\sympy\matrices\determinant.py:725, in _det_bareiss.<locals>.bareiss.<locals>.entry(i, j)
#     724 def entry(i, j):
# --> 725     ret = (pivot_val*tmp_mat[i, j + 1] - mat[pivot_pos, j + 1]*tmp_mat[i, 0]) / cumm
#     726     if _get_intermediate_simp_bool(True):
#     727         return _dotprodsimp(ret)
#
# File ~\anaconda3\lib\site-packages\sympy\core\decorators.py:65, in __sympifyit.<locals>.__sympifyit_wrapper(a, b)
#      63     if not hasattr(b, '_op_priority'):
#      64         b = sympify(b, strict=True)
# ---> 65     return func(a, b)
#      66 except SympifyError:
#      67     return retval
#
# File ~\anaconda3\lib\site-packages\sympy\core\numbers.py:1297, in Float.__mul__(self, other)
#    1295 if isinstance(other, Number) and global_parameters.evaluate:
#    1296     rhs, prec = other._as_mpf_op(self._prec)
# -> 1297     return Float._new(mlib.mpf_mul(self._mpf_, rhs, prec, rnd), prec)
#    1298 return Number.__mul__(self, other)
#
# File ~\anaconda3\lib\site-packages\sympy\core\numbers.py:1193, in Float._new(cls, _mpf_, _prec, zero)
#    1190     return S.NegativeInfinity
#    1192 obj = Expr.__new__(cls)
# -> 1193 obj._mpf_ = mpf_norm(_mpf_, _prec)
#    1194 obj._prec = _prec
#    1195 return obj
#
# File ~\anaconda3\lib\site-packages\sympy\core\numbers.py:173, in mpf_norm(mpf, prec)
#     170         return mpf
#     172 # Necessary if mpmath is using the gmpy backend
# --> 173 from mpmath.libmp.backend import MPZ
#     174 rv = mpf_normalize(sign, MPZ(man), expt, bc, prec, rnd)
#     175 return rv
#
# KeyboardInterrupt:
